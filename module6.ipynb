# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

#load in the dataset.
cancer_data = load_breast_cancer()

#create a df for features.
df_features = pd.DataFrame(cancer_data.data, columns=cancer_data.feature_names)

#create a df for target labels.
df_target = pd.DataFrame(cancer_data.target, columns=['target'])

#add the target df to the df with the features. 
df = pd.concat([df_features, df_target], axis=1)

#x_test are the features, y_test are the labels for the test dataset. 
#similarly, x_train are the features, and y_train and the labels for the training dataset.
#split the data into training and testing sets. Here I used the 80% 20% split. You can see that the test size is 0.2. 
x_train, x_test, y_train, y_test = train_test_split(df_features, cancer_data.target, test_size=0.2, random_state=42)

#train the model based on the x and y training splits I made. I was getting an error, so I had to set max_iter to 3000. 
model = LogisticRegression(max_iter=3000)
model.fit(x_train, y_train)

#predict on the test set.
y_pred = model.predict(x_test)

#use sklearn to calculate accuracy/f1 score. This uses the test and predicted.
report = f1_score(y_test, y_pred)
print("F1 Score:", report)
# Out:
# F1 Score: 0.9655172413793103

# %%
#look at where the predicted value does not equal the actual value.
misclassified_indices = np.where(y_pred != y_test)[0]

#print the examples.
for i in misclassified_indices[:5]:
    print("Misclassified Example:", i)
    print("Actual label:", y_test[i])
    print("Predicted label:", y_pred[i])
    print("Features:", x_test.iloc[i])
    print("----" * 10)
# Out:
# Misclassified Example: 20
# Actual label: 0
# Predicted label: 1
# Features: mean radius                 13.800000
# mean texture                15.790000
# mean perimeter              90.430000
# mean area                  584.100000
# mean smoothness              0.100700
# mean compactness             0.128000
# mean concavity               0.077890
# mean concave points          0.050690
# mean symmetry                0.166200
# mean fractal dimension       0.065660
# radius error                 0.278700
# texture error                0.620500
# perimeter error              1.957000
# area error                  23.350000
# smoothness error             0.004717
# compactness error            0.020650
# concavity error              0.017590
# concave points error         0.009206
# symmetry error               0.012200
# fractal dimension error      0.003130
# worst radius                16.570000
# worst texture               20.860000
# worst perimeter            110.300000
# worst area                 812.400000
# worst smoothness             0.141100
# worst compactness            0.354200
# worst concavity              0.277900
# worst concave points         0.138300
# worst symmetry               0.258900
# worst fractal dimension      0.103000
# Name: 73, dtype: float64
# ----------------------------------------
# Misclassified Example: 58
# Actual label: 0
# Predicted label: 1
# Features: mean radius                 13.480000
# mean texture                20.820000
# mean perimeter              88.400000
# mean area                  559.200000
# mean smoothness              0.101600
# mean compactness             0.125500
# mean concavity               0.106300
# mean concave points          0.054390
# mean symmetry                0.172000
# mean fractal dimension       0.064190
# radius error                 0.213000
# texture error                0.591400
# perimeter error              1.545000
# area error                  18.520000
# smoothness error             0.005367
# compactness error            0.022390
# concavity error              0.030490
# concave points error         0.012620
# symmetry error               0.013770
# fractal dimension error      0.003187
# worst radius                15.530000
# worst texture               26.020000
# worst perimeter            107.300000
# worst area                 740.400000
# worst smoothness             0.161000
# worst compactness            0.422500
# worst concavity              0.503000
# worst concave points         0.225800
# worst symmetry               0.280700
# worst fractal dimension      0.107100
# Name: 39, dtype: float64
# ----------------------------------------
# Misclassified Example: 77
# Actual label: 0
# Predicted label: 1
# Features: mean radius                 13.960000
# mean texture                17.050000
# mean perimeter              91.430000
# mean area                  602.400000
# mean smoothness              0.109600
# mean compactness             0.127900
# mean concavity               0.097890
# mean concave points          0.052460
# mean symmetry                0.190800
# mean fractal dimension       0.061300
# radius error                 0.425000
# texture error                0.809800
# perimeter error              2.563000
# area error                  35.740000
# smoothness error             0.006351
# compactness error            0.026790
# concavity error              0.031190
# concave points error         0.013420
# symmetry error               0.020620
# fractal dimension error      0.002695
# worst radius                16.390000
# worst texture               22.070000
# worst perimeter            108.100000
# worst area                 826.000000
# worst smoothness             0.151200
# worst compactness            0.326200
# worst concavity              0.320900
# worst concave points         0.137400
# worst symmetry               0.306800
# worst fractal dimension      0.079570
# Name: 255, dtype: float64
# ----------------------------------------
# Misclassified Example: 82
# Actual label: 0
# Predicted label: 1
# Features: mean radius                 14.480000
# mean texture                21.460000
# mean perimeter              94.250000
# mean area                  648.200000
# mean smoothness              0.094440
# mean compactness             0.099470
# mean concavity               0.120400
# mean concave points          0.049380
# mean symmetry                0.207500
# mean fractal dimension       0.056360
# radius error                 0.420400
# texture error                2.220000
# perimeter error              3.301000
# area error                  38.870000
# smoothness error             0.009369
# compactness error            0.029830
# concavity error              0.053710
# concave points error         0.017610
# symmetry error               0.024180
# fractal dimension error      0.003249
# worst radius                16.210000
# worst texture               29.250000
# worst perimeter            108.400000
# worst area                 808.900000
# worst smoothness             0.130600
# worst compactness            0.197600
# worst concavity              0.334900
# worst concave points         0.122500
# worst symmetry               0.302000
# worst fractal dimension      0.068460
# Name: 86, dtype: float64
# ----------------------------------------
# Misclassified Example: 112
# Actual label: 1
# Predicted label: 0
# Features: mean radius                 14.220000
# mean texture                27.850000
# mean perimeter              92.550000
# mean area                  623.900000
# mean smoothness              0.082230
# mean compactness             0.103900
# mean concavity               0.110300
# mean concave points          0.044080
# mean symmetry                0.134200
# mean fractal dimension       0.061290
# radius error                 0.335400
# texture error                2.324000
# perimeter error              2.105000
# area error                  29.960000
# smoothness error             0.006307
# compactness error            0.028450
# concavity error              0.038500
# concave points error         0.010110
# symmetry error               0.011850
# fractal dimension error      0.003589
# worst radius                15.750000
# worst texture               40.540000
# worst perimeter            102.500000
# worst area                 764.000000
# worst smoothness             0.108100
# worst compactness            0.242600
# worst concavity              0.306400
# worst concave points         0.082190
# worst symmetry               0.189000
# worst fractal dimension      0.077960
# Name: 238, dtype: float64
# ----------------------------------------

# %%
# data used: 
#https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html
#https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic
